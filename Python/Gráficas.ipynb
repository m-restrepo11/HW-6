# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
import numpy as npimport matplotlib.pyplot as pltdef cargar_datos(file):    """Carga el archivo con posiciones en un arreglo de numpy.Input: archivo con posiciones iniciales.Output: numpy array con todos los datos."""        #Carga los datos del archivo de entrada en dos arrays, uno con posición en X    #y otro con posición en Y.    pos_x= np.loadtxt(file, unpack=True, usecols=[1])    pos_y = np.loadtxt(file, unpack=True, usecols=[2])       return pos_x, pos_ydef make_plot(x, y):        """Hace las gráficas con las posisicones del arreglo cargado en el metodo cargar_datos.Input: Vector de posiciones en X, Vector de posiciones Y.Output: Gráficas."""    plt.plot(x,y, 'ko')    plt.xlabel('$Pos_X$', size=24)    plt.ylabel('$Pos_Y$',size=24)    plt.title('$Condiciones-Iniciales$', size=30)    #Defines the input fileinput_filename = 'condiciones_iniciales.dat'x,y= cargar_datos(input_filename)    cargar_datos(input_filename)make_plot(x, y)
